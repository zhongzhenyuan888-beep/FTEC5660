# %%
# !pip install uv > /dev/null 2>&1


# !uv venv myenv --python 3.10


# !uv pip install --python myenv metagpt
# Out:
# ...
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: myenv
# Activate with: source myenv/bin/activate
# Using Python 3.10.12 environment at: myenv
# Resolved 61 packages in 5.51s
# Prepared 61 packages in 2.73s
# Installed 61 packages in 277ms
#  + aiohttp==3.8.4
#  + aiosignal==1.4.0
#  + asgiref==3.11.1
#  + async-timeout==4.0.3
#  + attrs==25.4.0
#  + camel-converter==3.1.2
#  + certifi==2026.2.25
#  + channels==4.0.0
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + dataclasses-json==0.5.14
#  + diskcache==5.6.3
#  + django==5.2.11
#  + duckduckgo-search==2.9.4
#  + et-xmlfile==2.0.0
#  + exceptiongroup==1.3.1
#  + faiss-cpu==1.7.4
#  + fire==0.4.0
#  + frozenlist==1.8.0
#  + greenlet==3.3.2
#  + idna==3.11
#  + iniconfig==2.3.0
#  + langchain==0.0.231
#  + langchainplus-sdk==0.0.20
#  + loguru==0.6.0
#  + lxml==6.0.2
#  + marshmallow==3.26.2
#  + meilisearch==0.21.0
#  + metagpt==0.1
#  + multidict==6.7.1
#  + mypy-extensions==1.1.0
# ...

# %%
# !uv pip install --python myenv "metagpt>=0.8.0" --upgrade --prerelease=allow
# Out:
# Using Python 3.10.12 environment at: myenv
# Resolved 219 packages in 1.07s
# Prepared 187 packages in 20.63s
# Uninstalled 17 packages in 36ms
# Installed 187 packages in 501ms
#  + agentops==0.4.3
#  + aiofiles==23.2.1
#  - aiohttp==3.8.4
#  + aiohttp==3.8.6
#  + aiolimiter==1.2.1
#  + annotated-types==0.7.0
#  + anthropic==0.18.1
#  + anyio==4.12.1
#  + anytree==2.13.0
#  + asttokens==3.0.1
#  + bce-python-sdk==0.9.60
#  + beautifulsoup4==4.12.3
#  + boto3==1.34.162
#  + botocore==1.34.162
#  + cachetools==7.0.1
#  - camel-converter==3.1.2
#  + camel-converter==5.0.0
#  + cffi==2.0.0
#  + chardet==6.0.0.post1
#  + cloudpickle==3.1.2
#  + comm==0.2.3
#  + cryptography==43.0.3
#  + curl-cffi==0.7.4
#  + dashscope==1.19.3
#  + debugpy==1.8.20
#  + decorator==5.2.1
#  + deprecated==1.3.1
#  + deprecation==2.1.0
#  + dill==0.4.1
#  + distro==1.9.0
#  + dnspython==2.8.0
#  + executing==2.2.1
#  + farama-notifications==0.0.4
#  + fastjsonschema==2.21.2
#  + filelock==3.24.3
# ...

# %%
import os
from google.colab import userdata

api_key = userdata.get('AIHUBMIX_API_KEY')

config_content = f"""
llm:
  api_type: "openai"
  base_url: "https://aihubmix.com/v1"
  api_key: "{api_key}"
  model: "gemini-2.5-flash"
"""

os.makedirs(os.path.expanduser('~/.metagpt'), exist_ok=True)
with open(os.path.expanduser('~/.metagpt/config2.yaml'), 'w') as f:
    f.write(config_content)

print("✅ 配置文件已生成！当前底层模型：gemini-2.5-flash")
# Out:
# ✅ 配置文件已生成！当前底层模型：gemini-2.5-flash

# %%
# %%writefile run_baseline.py
import time
from metagpt.software_company import generate_repo

start_time = time.time()
print("🚀 开始运行：基于 [gemini-2.5-flash] 的软件开发团队")

repo = generate_repo("Create a simple Python command-line password generator.")

end_time = time.time()
print(f"✅ 任务完成！耗时: {end_time - start_time:.2f} 秒")
# Out:
# Writing run_baseline.py

# %%
# !myenv/bin/python run_baseline.py
# Out:
# /content/myenv/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# 2026-02-26 18:25:48.118 | INFO     | metagpt.const:get_metagpt_package_root:21 - Package root set to /content
# 🚀 开始运行：基于 [gemini-2.5-flash] 的软件开发团队
# /content/myenv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-02-26 18:25:58.433 | INFO     | metagpt.team:invest:93 - Investment: $3.0.
# ...

# %%
import os
from google.colab import userdata

api_key = userdata.get('AIHUBMIX_API_KEY')

# 将模型切换为 gemini-2.5-pro
config_content_pro = f"""
llm:
  api_type: "openai"
  base_url: "https://aihubmix.com/v1"
  api_key: "{api_key}"
  model: "gemini-2.5-pro"
"""

with open(os.path.expanduser('~/.metagpt/config2.yaml'), 'w') as f:
    f.write(config_content_pro)

print("🔄 变量控制：配置文件已切换为 gemini-2.5-pro")
# Out:
# 🔄 变量控制：配置文件已切换为 gemini-2.5-pro

# %%
# !myenv/bin/python run_baseline.py
# Out:
# /content/myenv/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# 2026-02-26 18:33:40.746 | INFO     | metagpt.const:get_metagpt_package_root:21 - Package root set to /content
# 🚀 开始运行：基于 [gemini-2.5-flash] 的软件开发团队
# /content/myenv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-02-26 18:33:47.356 | INFO     | metagpt.team:invest:93 - Investment: $3.0.
# ...

# %%
import os
from google.colab import userdata

api_key = userdata.get('AIHUBMIX_API_KEY')

# 将模型切换为 MetaGPT 最适配的 gpt-4-turbo
config_content_gpt = f"""
llm:
  api_type: "openai"
  base_url: "https://aihubmix.com/v1"
  api_key: "{api_key}"
  model: "gpt-4-turbo"
"""

with open(os.path.expanduser('~/.metagpt/config2.yaml'), 'w') as f:
    f.write(config_content_gpt)

print("🔄 变量控制：配置文件已切换为 [gpt-4-turbo] (对照成功组)")
# Out:
# 🔄 变量控制：配置文件已切换为 [gpt-4-turbo] (对照成功组)

# %%
# !myenv/bin/python run_baseline.py
# Out:
# /content/myenv/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# 2026-02-26 18:49:08.687 | INFO     | metagpt.const:get_metagpt_package_root:21 - Package root set to /content
# 🚀 开始运行：基于 [gemini-2.5-flash] 的软件开发团队
# /content/myenv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-02-26 18:49:14.903 | INFO     | metagpt.team:invest:93 - Investment: $3.0.
# ...
